# %% [markdown]
# ## <p style="text-align:center" color="red"><span style="color:red">Sentiment analysis on the Quran Karim Dataset - french version</span></p>
#
# <table align="center">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/labrijisaad/Sentiment-analysis-on-the-Quran-Karim-dataset"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>
#
# - In this notebook, I tried to write a script that can label the sentiment of a Quran Karim French Dataset using the **`pre-trained CamemBERT`** model.
# - Here is the model documentation: [**`pre-trained CamemBERT`**](https://camembert-model.fr/#:~:text=CamemBERT%3A%20a%20Tasty%20French%20Language,achieves%20strong%20results%20in%20NLI.)
#
#
# > 🙌 Notebook made by [@labriji_saad](https://github.com/labrijisaad)

# %% [markdown]
# ### Importing the requirements

# %%
# %%capture
import pandas as pd
import numpy as np
from yaspin import yaspin

# %% [markdown]
# ### Reading the **`wolof Quran Karim Dataset`**

# %%
df_wolof = pd.read_csv("Quran Karim wolof.csv", encoding='utf-8-sig')
df_wolof
# Out:
#       index sourat  index verse         name sourat in wolof  \
# 0                1            1   ubbiku ga saar wu jëkk wi
# 1                1            2   ubbiku ga saar wu jëkk wi
# 2                1            3   ubbiku ga saar wu jëkk wi
# 3                1            4   ubbiku ga saar wu jëkk wi
# 4                1            5   ubbiku ga saar wu jëkk wi
# ...            ...          ...                          ...
# 6231           114            2                       nit ñi
# 6232           114            3                       nit ñi
# 6233           114            4                       nit ñi
# 6234           114            5                       nit ñi
# 6235           114            6                       nit ñi
#
#                                          verse in wolof
# 0      Ci turu Yàlla, miy Yërëmaakoon , di Jaglewaak...
# 1      Xeeti cant yépp ñeel na Yàlla, miy Boroom àdd...
# 2                      Yërëmaakoon bi, Jaglewaakoon bi,
# 3                       Di Buur, di Boroom Bis-pénc ba.
# 4     Yaw doŋŋ la nuy jaamu, te ci Yaw doŋŋ doŋŋ la ...
# ...                                                 ...
# 6231                                 Kiy Buurub nit ñi,
# 6232                                   Di Yàlla nit ñi,
# 6233                       ci ayu jax-jaxali, Saytaane,
# 6234                kiy jax-jaxal ci biir dënni nit ñi,
# 6235                     te bokk ci jinne yeek nit ñi”.
#
# [6236 rows x 4 columns]

# %% [markdown]
# ### Reading the **`french Quran Karim Dataset`**

# %%
df_french = pd.read_csv("Quran Karim french.csv", encoding='utf-8')
df_french
# Out:
#       index sourat  index verse name sourat in french  \
# 0                1            1            al fatiha
# 1                1            2            al fatiha
# 2                1            3            al fatiha
# 3                1            4            al fatiha
# 4                1            5            al fatiha
# ...            ...          ...                   ...
# 6231           114            2               an nas
# 6232           114            3               an nas
# 6233           114            4               an nas
# 6234           114            5               an nas
# 6235           114            6               an nas
#
#                                         verse in french
# 0      au nom d allah le tout miséricordieux le très...
# 1                louange à allah seigneur de l univers
# 2        le tout miséricordieux le très miséricordieux
# 3                     maître du jour de la rétribution
# 4      c est toi seul que nous adorons et c est toi ...
# ...                                                 ...
# 6231                           le souverain des hommes
# 6232                                   dieu des hommes
# 6233        contre le mal du mauvais conseiller furtif
# 6234   qui souffle le mal dans les poitrines des hom...
# 6235   qu il le conseiller soit un djinn ou un être ...
#
# [6236 rows x 4 columns]

# %% [markdown]
# ### Merging the TWO datasets

# %%
index_sourat = df_french['index sourat'].tolist()
index_verse = df_french['index verse'].tolist()
verse_in_french = df_french['verse in french'].tolist()
name_sourat_in_french = df_french['name sourat in french'].tolist()

verse_in_wolof = df_wolof['verse in wolof'].tolist()
name_sourat_in_wolof = df_wolof['name sourat in wolof'].tolist()

df = pd.DataFrame()
df["index sourat"] = index_sourat
df["index verse"] = index_verse
df["name sourat in french"] = name_sourat_in_french
df["name sourat in wolof"] = name_sourat_in_wolof
df["verse in french"] = verse_in_french
df["verse in wolof"] = verse_in_wolof

df
# Out:
#       index sourat  index verse name sourat in french  \
# 0                1            1            al fatiha
# 1                1            2            al fatiha
# 2                1            3            al fatiha
# 3                1            4            al fatiha
# 4                1            5            al fatiha
# ...            ...          ...                   ...
# 6231           114            2               an nas
# 6232           114            3               an nas
# 6233           114            4               an nas
# 6234           114            5               an nas
# 6235           114            6               an nas
#
#              name sourat in wolof  \
# 0      ubbiku ga saar wu jëkk wi
# 1      ubbiku ga saar wu jëkk wi
# 2      ubbiku ga saar wu jëkk wi
# 3      ubbiku ga saar wu jëkk wi
# 4      ubbiku ga saar wu jëkk wi
# ...                           ...
# 6231                       nit ñi
# 6232                       nit ñi
# 6233                       nit ñi
# 6234                       nit ñi
# 6235                       nit ñi
#
#                                         verse in french  \
# 0      au nom d allah le tout miséricordieux le très...
# 1                louange à allah seigneur de l univers
# 2        le tout miséricordieux le très miséricordieux
# 3                     maître du jour de la rétribution
# 4      c est toi seul que nous adorons et c est toi ...
# ...                                                 ...
# 6231                           le souverain des hommes
# 6232                                   dieu des hommes
# 6233        contre le mal du mauvais conseiller furtif
# 6234   qui souffle le mal dans les poitrines des hom...
# 6235   qu il le conseiller soit un djinn ou un être ...
#
#                                          verse in wolof
# 0      Ci turu Yàlla, miy Yërëmaakoon , di Jaglewaak...
# 1      Xeeti cant yépp ñeel na Yàlla, miy Boroom àdd...
# 2                      Yërëmaakoon bi, Jaglewaakoon bi,
# 3                       Di Buur, di Boroom Bis-pénc ba.
# 4     Yaw doŋŋ la nuy jaamu, te ci Yaw doŋŋ doŋŋ la ...
# ...                                                 ...
# 6231                                 Kiy Buurub nit ñi,
# 6232                                   Di Yàlla nit ñi,
# 6233                       ci ayu jax-jaxali, Saytaane,
# 6234                kiy jax-jaxal ci biir dënni nit ñi,
# 6235                     te bokk ci jinne yeek nit ñi”.
#
# [6236 rows x 6 columns]

# %% [markdown]
# > Now, we have a Wolof-French parallel dataset, the next step is to run a pre-trained sentiment analysis model on the **`verse in French`** column:  **In this way we get a labeled wolof dataset.**

# %% [markdown]
# ## <p style="text-align:center" color="red"><span style="color:red"> Sentiment analysis with a pre-trained CamemBERT  model </span></p>

# %% [markdown]
# ### Importing the necessary libraries

# %%
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import pipeline
from tqdm import tqdm

# %%
tokenizer = AutoTokenizer.from_pretrained("tblard/tf-allocine")
model = TFAutoModelForSequenceClassification.from_pretrained("tblard/tf-allocine")
nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
# Out:
# All model checkpoint layers were used when initializing TFCamembertForSequenceClassification.
#
# All the layers of TFCamembertForSequenceClassification were initialized from the model checkpoint at tblard/tf-allocine.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFCamembertForSequenceClassification for predictions without further training.

# %%
# Testing the operation of the model
print(nlp("Deux choses donnent la paix en ce monde : l’honnêteté et la piété")) # sentence extracted from the dataset.
# Out:
# [{'label': 'POSITIVE', 'score': 0.9348116517066956}]

# %% [markdown]
# ### Sentiment Analysis with CamemBERT model

# %%
tqdm.pandas()

def predict_with_CamemBERT(text):
    sentiment_result = nlp(text)
    return str(sentiment_result)[12:20]

df['sentiment with CamemBERT-french model'] = df['verse in french'].progress_apply(predict_with_CamemBERT)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 6236/6236 [24:08<00:00,  4.31it/s]

# %%
df
# Out:
#       index sourat  index verse name sourat in french  \
# 0                1            1            al fatiha
# 1                1            2            al fatiha
# 2                1            3            al fatiha
# 3                1            4            al fatiha
# 4                1            5            al fatiha
# ...            ...          ...                   ...
# 6231           114            2               an nas
# 6232           114            3               an nas
# 6233           114            4               an nas
# 6234           114            5               an nas
# 6235           114            6               an nas
#
#              name sourat in wolof  \
# 0      ubbiku ga saar wu jëkk wi
# 1      ubbiku ga saar wu jëkk wi
# 2      ubbiku ga saar wu jëkk wi
# 3      ubbiku ga saar wu jëkk wi
# 4      ubbiku ga saar wu jëkk wi
# ...                           ...
# 6231                       nit ñi
# 6232                       nit ñi
# 6233                       nit ñi
# 6234                       nit ñi
# 6235                       nit ñi
#
#                                         verse in french  \
# 0      au nom d allah le tout miséricordieux le très...
# 1                louange à allah seigneur de l univers
# 2        le tout miséricordieux le très miséricordieux
# 3                     maître du jour de la rétribution
# 4      c est toi seul que nous adorons et c est toi ...
# ...                                                 ...
# 6231                           le souverain des hommes
# 6232                                   dieu des hommes
# 6233        contre le mal du mauvais conseiller furtif
# 6234   qui souffle le mal dans les poitrines des hom...
# 6235   qu il le conseiller soit un djinn ou un être ...
#
#                                          verse in wolof  \
# 0      Ci turu Yàlla, miy Yërëmaakoon , di Jaglewaak...
# 1      Xeeti cant yépp ñeel na Yàlla, miy Boroom àdd...
# 2                      Yërëmaakoon bi, Jaglewaakoon bi,
# 3                       Di Buur, di Boroom Bis-pénc ba.
# 4     Yaw doŋŋ la nuy jaamu, te ci Yaw doŋŋ doŋŋ la ...
# ...                                                 ...
# 6231                                 Kiy Buurub nit ñi,
# 6232                                   Di Yàlla nit ñi,
# 6233                       ci ayu jax-jaxali, Saytaane,
# 6234                kiy jax-jaxal ci biir dënni nit ñi,
# 6235                     te bokk ci jinne yeek nit ñi”.
#
#      sentiment with CamemBERT-french model
# 0                                 POSITIVE
# 1                                 POSITIVE
# 2                                 POSITIVE
# 3                                 POSITIVE
# 4                                 POSITIVE
# ...                                    ...
# 6231                              POSITIVE
# 6232                              POSITIVE
# 6233                              POSITIVE
# 6234                              POSITIVE
# 6235                              POSITIVE
#
# [6236 rows x 7 columns]

# %% [markdown]
# ### Saving the dataset

# %%
df.to_csv("Quran Karim wolof-labeled.csv", encoding="utf-8-sig", index=False)
df = pd.read_csv("Quran Karim wolof-labeled.csv", encoding='utf-8-sig')
df
# Out:
#       index sourat  index verse name sourat in french  \
# 0                1            1            al fatiha
# 1                1            2            al fatiha
# 2                1            3            al fatiha
# 3                1            4            al fatiha
# 4                1            5            al fatiha
# ...            ...          ...                   ...
# 6231           114            2               an nas
# 6232           114            3               an nas
# 6233           114            4               an nas
# 6234           114            5               an nas
# 6235           114            6               an nas
#
#              name sourat in wolof  \
# 0      ubbiku ga saar wu jëkk wi
# 1      ubbiku ga saar wu jëkk wi
# 2      ubbiku ga saar wu jëkk wi
# 3      ubbiku ga saar wu jëkk wi
# 4      ubbiku ga saar wu jëkk wi
# ...                           ...
# 6231                       nit ñi
# 6232                       nit ñi
# 6233                       nit ñi
# 6234                       nit ñi
# 6235                       nit ñi
#
#                                         verse in french  \
# 0      au nom d allah le tout miséricordieux le très...
# 1                louange à allah seigneur de l univers
# 2        le tout miséricordieux le très miséricordieux
# 3                     maître du jour de la rétribution
# 4      c est toi seul que nous adorons et c est toi ...
# ...                                                 ...
# 6231                           le souverain des hommes
# 6232                                   dieu des hommes
# 6233        contre le mal du mauvais conseiller furtif
# 6234   qui souffle le mal dans les poitrines des hom...
# 6235   qu il le conseiller soit un djinn ou un être ...
#
#                                          verse in wolof  \
# 0      Ci turu Yàlla, miy Yërëmaakoon , di Jaglewaak...
# 1      Xeeti cant yépp ñeel na Yàlla, miy Boroom àdd...
# 2                      Yërëmaakoon bi, Jaglewaakoon bi,
# 3                       Di Buur, di Boroom Bis-pénc ba.
# 4     Yaw doŋŋ la nuy jaamu, te ci Yaw doŋŋ doŋŋ la ...
# ...                                                 ...
# 6231                                 Kiy Buurub nit ñi,
# 6232                                   Di Yàlla nit ñi,
# 6233                       ci ayu jax-jaxali, Saytaane,
# 6234                kiy jax-jaxal ci biir dënni nit ñi,
# 6235                     te bokk ci jinne yeek nit ñi”.
#
#      sentiment with CamemBERT-french model
# 0                                 POSITIVE
# 1                                 POSITIVE
# 2                                 POSITIVE
# 3                                 POSITIVE
# 4                                 POSITIVE
# ...                                    ...
# 6231                              POSITIVE
# 6232                              POSITIVE
# 6233                              POSITIVE
# 6234                              POSITIVE
# 6235                              POSITIVE
#
# [6236 rows x 7 columns]

# %% [markdown]
# > - 🙌 Notebook made by [@labriji_saad](https://github.com/labrijisaad)
# > - 🔗 Linledin [@labriji_saad](https://www.linkedin.com/in/labrijisaad/)
